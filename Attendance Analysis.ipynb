# %% [markdown]
# # Network Data Strategist

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import from csv
attendance_df = pd.read_csv('Attendance.csv')
#Original df
attendance_df
# Out:
#       School ID     Network                 Group  Grade  2015  2016  2017
# 0           NaN         NaN  All (Excludes Pre-K)    NaN  93.2  93.4  92.8
# 1           NaN         NaN                 Grade  Pre-K  89.2  89.6  88.8
# 2           NaN         NaN                 Grade      K  93.7  94.2  93.7
# 3           NaN         NaN                 Grade      1  94.5  95.0  94.5
# 4           NaN         NaN                 Grade      2  95.1  95.5  95.0
# ...         ...         ...                   ...    ...   ...   ...   ...
# 7536   610588.0  Network 10  All (Excludes Pre-K)    NaN   NaN   NaN  94.8
# 7537   610588.0  Network 10                 Grade      5   NaN   NaN  95.1
# 7538   610588.0  Network 10                 Grade      6   NaN   NaN  95.7
# 7539   610588.0  Network 10                 Grade      7   NaN   NaN  94.9
# 7540   610588.0  Network 10                 Grade      8   NaN   NaN  93.6
#
# [7541 rows x 7 columns]

# %%
attendance_df['School ID'] = attendance_df['School ID'].fillna(method='ffill')
attendance_df['Network'] = attendance_df['Network'].fillna(method='ffill')

# %%
#Drop rows with any null values in '2015', '2016', '2017'
attendance_df = attendance_df.dropna(subset=['2015', '2016', '2017'])

# %%
network_12_attendance_df = attendance_df[attendance_df['Network'] == 'Network 12']
network_12_attendance_df
# Out:
#       School ID     Network                 Group Grade  2015  2016  2017
# 1122   609674.0  Network 12  All (Excludes Pre-K)   NaN  86.5  87.3  83.7
# 1124   609674.0  Network 12                 Grade     9  85.9  88.2  83.3
# 1125   609674.0  Network 12                 Grade    10  86.1  86.5  82.7
# 1126   609674.0  Network 12                 Grade    11  86.8  86.6  83.9
# 1127   609674.0  Network 12                 Grade    12  87.6  87.7  84.9
# ...         ...         ...                   ...   ...   ...   ...   ...
# 7361   610547.0  Network 12  All (Excludes Pre-K)   NaN  87.0  90.2  90.1
# 7362   610547.0  Network 12                 Grade     9  94.2  92.0  92.7
# 7363   610547.0  Network 12                 Grade    10  88.8  92.9  91.2
# 7364   610547.0  Network 12                 Grade    11  87.7  89.2  91.6
# 7365   610547.0  Network 12                 Grade    12  81.5  86.2  83.7
#
# [354 rows x 7 columns]

# %%
# Calculate the mean attendance for each year
average_attendance_per_year = network_12_attendance_df[['2015', '2016', '2017']].mean()

# %%
# Plot the average attendance trend
plt.figure(figsize=(10, 6))
plt.plot(average_attendance_per_year.index, average_attendance_per_year.values, marker='o', linestyle='-', color='b')
plt.title('Average Attendance Trend in Network 12 (2015-2017)', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Average Attendance Rate (%)', fontsize=14)
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
